# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('pokemon.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
f, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt='.1f', ax=ax)

# %%
print data.shape
data.head(10)
# Out:
# (800, 12)
#     #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1   2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2   3          Venusaur  Grass  Poison  80      82       83      100      100
# 3   4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4   5        Charmander   Fire     NaN  39      52       43       60       50
# 5   6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6   7         Charizard   Fire  Flying  78      84       78      109       85
# 7   8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   9  Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9  10          Squirtle  Water     NaN  44      48       65       50       64
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False
# 5     80           1      False
# 6    100           1      False
# 7    100           1      False
# 8    100           1      False
# 9     43           1      False

# %%
data.Speed.plot(kind='line',color='g',label='speed',linewidth=1,alpha=0.5,grid=True,linestyle=':')
data.Defense.plot(kind='line',color='r',label='defense',linewidth=1,alpha=0.5,grid=True,linestyle=':')
plt.legend(loc='upper right')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Plot')

# %%
data.plot(kind='scatter', x='Attack', y='Defense', alpha = 0.5, color='red')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.title('Attack Defense scatter plot')

# %%
data.Speed.plot(kind = 'hist', bins = 50, figsize=(15,15))

# %%
dictionary = {'spain':'madrid', 'usa':'vegas'}
print dictionary.keys()
print dictionary.values()
# Out:
# ['usa', 'spain']
# ['vegas', 'madrid']

# %%
dictionary['spain'] = 'barcelona'
print dictionary
dictionary['france'] = 'paris'
print dictionary
del dictionary['spain']
print dictionary
print 'france' in dictionary
dictionary.clear()
print dictionary
# Out:
# {'usa': 'vegas', 'spain': 'barcelona'}
# {'usa': 'vegas', 'spain': 'barcelona', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %%
print dictionary
# Out:
# {}

# %%
data = pd.read_csv('pokemon.csv')

# %%
series = data['Defense']
print type(series)
data_frame = data[['Defense']]
print type(data_frame)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
print series.shape
print data_frame.shape
# Out:
# (800,)
# (800, 1)

# %%
x = data['Defense'] > 200
data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %%
data[np.logical_and(data['Defense']>200, data['Attack']>100 )]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
data[(data['Defense']>200) & (data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
number_list = [1,2,3]
y = map(lambda x:x**2,number_list)
print type(y)
print(list(y))
# Out:
# <type 'list'>
# [1, 4, 9]

# %%
threshold = sum(data.Speed)/len(data.Speed)
data["speed_level"] = ["high" if i > threshold else "low" for i in data.Speed]
data.loc[:10,["speed_level","Speed"]]
# Out:
#    speed_level  Speed
# 0          low     45
# 1          low     60
# 2         high     80
# 3         high     80
# 4          low     65
# 5         high     80
# 6         high    100
# 7         high    100
# 8         high    100
# 9          low     43
# 10         low     58

# %%
data = pd.read_csv('pokemon.csv')
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
print data['Type 1'].value_counts(dropna=False)
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
data.boxplot(column='Attack', by ='Legendary')

# %%
data_new=data.head()
data_new
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
melted = pd.melt(frame=data_new,id_vars='Name',value_vars=['Attack','Defense'])
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %%
melted.pivot(index = 'Name', columns = 'variable',values='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %%
# Firstly lets create 2 data frame
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) # axis = 0 : adds dataframes in row
conc_data_row
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5      150     50           6       True
# 6      110    110           6       True
# 7      130     70           6       True
# 8      130     80           6       True
# 9       90     70           6       True

# %%
data1 = data['Attack'].head()
data2= data['Defense'].head()
conc_data_col = pd.concat([data1,data2],axis =1)
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
data['Type 1'] = data['Type 1'].astype('category')
data['Speed'] = data['Speed'].astype('float')

# %%
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null category
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null float64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
data['Type 2'].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Rock         14
# Water        14
# Ghost        14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data1 = data
data1['Type 2'].dropna(inplace =True)

# %%
assert data['Type 2'].notnull().all()

# %%
data['Type 2'].fillna('empty', inplace =True)

# %%
assert data['Type 2'].notnull().all()

# %%
# data frames from dictionary
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country,population]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
df['capital']=['madrid','paris']
df['income'] = 0
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %%
data1 = data.loc[:,['Attack','Defense','Speed']]
data1.plot()

# %%
data1.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbe6452e290>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbe64290890>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbe64199850>], dtype=object)

# %%
# scatter plot  
data1.plot(kind = "scatter",x="Attack",y = "Defense")

# %%
# hist plot  
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True)

# %%
fig, axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind='hist',y='Defense',bins=50,range=(0,250),normed=True,ax=axes[0])
data1.plot(kind='hist',y='Defense',bins=50,range=(0,250),normed=True,ax=axes[1],cumulative=True)

# %%
time_list = ['1992-03-08', '1992-04-12']
print type(time_list[1])
datetime_object = pd.to_datetime(time_list)
print type(datetime_object)
# Out:
# <type 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data2 = data.head()
date_list = ['1992-01-10', '1992-02-10','1992-03-10', '1993-03-15', '1993-03-16']
datetime_object = pd.to_datetime(date_list)
data2['date']=datetime_object
data2=data2.set_index('date')
data2
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
print data2.loc['1993-03-16']
print data2.loc['1992-03-10' : '1993-03-16']
# Out:
# #                      5
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 1993-03-16 00:00:00, dtype: object
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
data2.resample('A').mean()
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0      False
# 1993-12-31  72.500000         1.0      False

# %%
data2.resample('M').mean()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-12-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-01-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-02-28  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-03-31  4.5  59.5    76.0     83.0     91.0     85.0   72.5         1.0
#
#             Legendary
# date
# 1992-01-31        0.0
# 1992-02-29        0.0
# 1992-03-31        0.0
# 1992-04-30        NaN
# 1992-05-31        NaN
# 1992-06-30        NaN
# 1992-07-31        NaN
# 1992-08-31        NaN
# 1992-09-30        NaN
# 1992-10-31        NaN
# 1992-11-30        NaN
# 1992-12-31        NaN
# 1993-01-31        NaN
# 1993-02-28        NaN
# 1993-03-31        0.0

# %%
data2.resample('M').first().interpolate('linear')
# Out:
#                    #           Name Type 1  Type 2    HP  Attack     Defense  \
# date
# 1992-01-31  1.000000      Bulbasaur  Grass  Poison  45.0    49.0   49.000000
# 1992-02-29  2.000000        Ivysaur  Grass  Poison  60.0    62.0   63.000000
# 1992-03-31  3.000000       Venusaur  Grass  Poison  80.0    82.0   83.000000
# 1992-04-30  3.083333            NaN    NaN     NaN  80.0    83.5   86.333333
# 1992-05-31  3.166667            NaN    NaN     NaN  80.0    85.0   89.666667
# 1992-06-30  3.250000            NaN    NaN     NaN  80.0    86.5   93.000000
# 1992-07-31  3.333333            NaN    NaN     NaN  80.0    88.0   96.333333
# 1992-08-31  3.416667            NaN    NaN     NaN  80.0    89.5   99.666667
# 1992-09-30  3.500000            NaN    NaN     NaN  80.0    91.0  103.000000
# 1992-10-31  3.583333            NaN    NaN     NaN  80.0    92.5  106.333333
# 1992-11-30  3.666667            NaN    NaN     NaN  80.0    94.0  109.666667
# 1992-12-31  3.750000            NaN    NaN     NaN  80.0    95.5  113.000000
# 1993-01-31  3.833333            NaN    NaN     NaN  80.0    97.0  116.333333
# 1993-02-28  3.916667            NaN    NaN     NaN  80.0    98.5  119.666667
# 1993-03-31  4.000000  Mega Venusaur  Grass  Poison  80.0   100.0  123.000000
#
#                Sp. Atk     Sp. Def  Speed  Generation Legendary
# date
# 1992-01-31   65.000000   65.000000   45.0         1.0     False
# 1992-02-29   80.000000   80.000000   60.0         1.0     False
# 1992-03-31  100.000000  100.000000   80.0         1.0     False
# 1992-04-30  101.833333  101.666667   80.0         1.0       NaN
# 1992-05-31  103.666667  103.333333   80.0         1.0       NaN
# 1992-06-30  105.500000  105.000000   80.0         1.0       NaN
# 1992-07-31  107.333333  106.666667   80.0         1.0       NaN
# 1992-08-31  109.166667  108.333333   80.0         1.0       NaN
# 1992-09-30  111.000000  110.000000   80.0         1.0       NaN
# 1992-10-31  112.833333  111.666667   80.0         1.0       NaN
# 1992-11-30  114.666667  113.333333   80.0         1.0       NaN
# 1992-12-31  116.500000  115.000000   80.0         1.0       NaN
# 1993-01-31  118.333333  116.666667   80.0         1.0       NaN
# 1993-02-28  120.166667  118.333333   80.0         1.0       NaN
# 1993-03-31  122.000000  120.000000   80.0         1.0     False

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#                 #         HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# date
# 1992-01-31  1.000  45.000000    49.0     49.0    65.00    65.00  45.000
# 1992-02-29  2.000  60.000000    62.0     63.0    80.00    80.00  60.000
# 1992-03-31  3.000  80.000000    82.0     83.0   100.00   100.00  80.000
# 1992-04-30  3.125  78.291667    81.5     83.0    99.25    98.75  79.375
# 1992-05-31  3.250  76.583333    81.0     83.0    98.50    97.50  78.750
# 1992-06-30  3.375  74.875000    80.5     83.0    97.75    96.25  78.125
# 1992-07-31  3.500  73.166667    80.0     83.0    97.00    95.00  77.500
# 1992-08-31  3.625  71.458333    79.5     83.0    96.25    93.75  76.875
# 1992-09-30  3.750  69.750000    79.0     83.0    95.50    92.50  76.250
# 1992-10-31  3.875  68.041667    78.5     83.0    94.75    91.25  75.625
# 1992-11-30  4.000  66.333333    78.0     83.0    94.00    90.00  75.000
# 1992-12-31  4.125  64.625000    77.5     83.0    93.25    88.75  74.375
# 1993-01-31  4.250  62.916667    77.0     83.0    92.50    87.50  73.750
# 1993-02-28  4.375  61.208333    76.5     83.0    91.75    86.25  73.125
# 1993-03-31  4.500  59.500000    76.0     83.0    91.00    85.00  72.500
#
#             Generation  Legendary
# date
# 1992-01-31         1.0        0.0
# 1992-02-29         1.0        0.0
# 1992-03-31         1.0        0.0
# 1992-04-30         1.0        0.0
# 1992-05-31         1.0        0.0
# 1992-06-30         1.0        0.0
# 1992-07-31         1.0        0.0
# 1992-08-31         1.0        0.0
# 1992-09-30         1.0        0.0
# 1992-10-31         1.0        0.0
# 1992-11-30         1.0        0.0
# 1992-12-31         1.0        0.0
# 1993-01-31         1.0        0.0
# 1993-02-28         1.0        0.0
# 1993-03-31         1.0        0.0

# %%
data = pd.read_csv('pokemon.csv')
data = data.set_index('#')
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
data['HP'][1]
# Out:
# 45

# %%
data.HP[1]
# Out:
# 45

# %%
data.loc[1,['HP']]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
data[['HP','Attack']]
# Out:
#       HP  Attack
# #
# 1     45      49
# 2     60      62
# 3     80      82
# 4     80     100
# 5     39      52
# 6     58      64
# 7     78      84
# 8     78     130
# 9     78     104
# 10    44      48
# 11    59      63
# 12    79      83
# 13    79     103
# 14    45      30
# 15    50      20
# 16    60      45
# 17    40      35
# 18    45      25
# 19    65      90
# 20    65     150
# 21    40      45
# 22    63      60
# 23    83      80
# 24    83      80
# 25    30      56
# 26    55      81
# 27    40      60
# 28    65      90
# 29    35      60
# 30    60      85
# ..   ...     ...
# 771   95      65
# 772   78      92
# 773   67      58
# 774   50      50
# 775   45      50
# 776   68      75
# 777   90     100
# 778   57      80
# 779   43      70
# 780   85     110
# 781   49      66
# 782   44      66
# 783   54      66
# 784   59      66
# 785   65      90
# 786   55      85
# 787   75      95
# 788   85     100
# 789   55      69
# 790   95     117
# 791   40      30
# 792   85      70
# 793  126     131
# 794  126     131
# 795  108     100
# 796   50     100
# 797   50     160
# 798   80     110
# 799   80     160
# 800   80     110
#
# [800 rows x 2 columns]

# %%
print type(data['HP'])
print type(data[['HP']])
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data.loc[1:10,'HP':'Defense']
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 4   80     100      123
# 5   39      52       43
# 6   58      64       58
# 7   78      84       78
# 8   78     130      111
# 9   78     104       78
# 10  44      48       65

# %%
data.loc[10:1:-1,'HP':'Defense']
# Out:
#     HP  Attack  Defense
# #
# 10  44      48       65
# 9   78     104       78
# 8   78     130      111
# 7   78      84       78
# 6   58      64       58
# 5   39      52       43
# 4   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
data.loc[1:10,'Speed':]
# Out:
#     Speed  Generation  Legendary
# #
# 1      45           1      False
# 2      60           1      False
# 3      80           1      False
# 4      80           1      False
# 5      65           1      False
# 6      80           1      False
# 7     100           1      False
# 8     100           1      False
# 9     100           1      False
# 10     43           1      False

# %%
boolean = data.HP > 200
data[boolean]
# Out:
#         Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122  Chansey  Normal    NaN  250       5        5       35      105     50
# 262  Blissey  Normal    NaN  255      10       10       75      135     55
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False

# %%
first_filter = data.HP > 150
second_filter = data.Speed > 35
data[first_filter & second_filter]
# Out:
#           Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122    Chansey  Normal    NaN  250       5        5       35      105     50
# 262    Blissey  Normal    NaN  255      10       10       75      135     55
# 352    Wailord   Water    NaN  170      90       45       90       45     60
# 656  Alomomola   Water    NaN  165      75       80       40       45     65
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False
# 352           3      False
# 656           5      False

# %%
data[data.Speed<15]
# Out:
#           Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 231    Shuckle     Bug   Rock   20      10      230       10      230      5
# 360   Trapinch  Ground    NaN   45     100       45       45       45     10
# 487     Bonsly    Rock    NaN   50      80       95       10       45     10
# 496   Munchlax  Normal    NaN  135      85       40       40       85      5
# 659  Ferroseed   Grass  Steel   44      50       91       24       86     10
#
#      Generation  Legendary
# #
# 231           2      False
# 360           3      False
# 487           4      False
# 496           4      False
# 659           5      False

# %%
def div(n):
    return n/2.0
data.HP.apply(div)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
# 6      29.0
# 7      39.0
# 8      39.0
# 9      39.0
# 10     22.0
# 11     29.5
# 12     39.5
# 13     39.5
# 14     22.5
# 15     25.0
# 16     30.0
# 17     20.0
# 18     22.5
# 19     32.5
# 20     32.5
# 21     20.0
# 22     31.5
# 23     41.5
# 24     41.5
# 25     15.0
# 26     27.5
# 27     20.0
# 28     32.5
# 29     17.5
# 30     30.0
#        ...
# 771    47.5
# 772    39.0
# 773    33.5
# 774    25.0
# 775    22.5
# 776    34.0
# 777    45.0
# 778    28.5
# 779    21.5
# 780    42.5
# 781    24.5
# 782    22.0
# 783    27.0
# 784    29.5
# 785    32.5
# 786    27.5
# 787    37.5
# 788    42.5
# 789    27.5
# 790    47.5
# 791    20.0
# 792    42.5
# 793    63.0
# 794    63.0
# 795    54.0
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data.HP.apply(lambda n :n/2.0)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
# 6      29.0
# 7      39.0
# 8      39.0
# 9      39.0
# 10     22.0
# 11     29.5
# 12     39.5
# 13     39.5
# 14     22.5
# 15     25.0
# 16     30.0
# 17     20.0
# 18     22.5
# 19     32.5
# 20     32.5
# 21     20.0
# 22     31.5
# 23     41.5
# 24     41.5
# 25     15.0
# 26     27.5
# 27     20.0
# 28     32.5
# 29     17.5
# 30     30.0
#        ...
# 771    47.5
# 772    39.0
# 773    33.5
# 774    25.0
# 775    22.5
# 776    34.0
# 777    45.0
# 778    28.5
# 779    21.5
# 780    42.5
# 781    24.5
# 782    22.0
# 783    27.0
# 784    29.5
# 785    32.5
# 786    27.5
# 787    37.5
# 788    42.5
# 789    27.5
# 790    47.5
# 791    20.0
# 792    42.5
# 793    63.0
# 794    63.0
# 795    54.0
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data['total _power']=data.Attack + data.Defense
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary  total _power
# #
# 1           1      False            98
# 2           1      False           125
# 3           1      False           165
# 4           1      False           223
# 5           1      False            95

# %%
print data.index.name
data.index.name = 'index_name'
data.head()
# Out:
# #
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 1               Bulbasaur  Grass  Poison  45      49       49       65
# 2                 Ivysaur  Grass  Poison  60      62       63       80
# 3                Venusaur  Grass  Poison  80      82       83      100
# 4           Mega Venusaur  Grass  Poison  80     100      123      122
# 5              Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total _power
# index_name
# 1                65     45           1      False            98
# 2                80     60           1      False           125
# 3               100     80           1      False           165
# 4               120     80           1      False           223
# 5                50     65           1      False            95

# %%
data.head()
data3 = data.copy()
data3.index=range(100,1700,2)
data3.head()
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100      Bulbasaur  Grass  Poison  45      49       49       65       65
# 102        Ivysaur  Grass  Poison  60      62       63       80       80
# 104       Venusaur  Grass  Poison  80      82       83      100      100
# 106  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 108     Charmander   Fire     NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  total _power
# 100     45           1      False            98
# 102     60           1      False           125
# 104     80           1      False           165
# 106     80           1      False           223
# 108     65           1      False            95

# %%
data = pd.read_csv('pokemon.csv')

# %%
data1 = data.set_index(['Type 1', 'Type 2'])
data1.head(100)
# Out:
#                     #              Name   HP  Attack  Defense  Sp. Atk  \
# Type 1   Type 2
# Grass    Poison     1         Bulbasaur   45      49       49       65
#          Poison     2           Ivysaur   60      62       63       80
#          Poison     3          Venusaur   80      82       83      100
#          Poison     4     Mega Venusaur   80     100      123      122
# Fire     NaN        5        Charmander   39      52       43       60
#          NaN        6        Charmeleon   58      64       58       80
#          Flying     7         Charizard   78      84       78      109
#          Dragon     8  Mega Charizard X   78     130      111      130
#          Flying     9  Mega Charizard Y   78     104       78      159
# Water    NaN       10          Squirtle   44      48       65       50
#          NaN       11         Wartortle   59      63       80       65
#          NaN       12         Blastoise   79      83      100       85
#          NaN       13    Mega Blastoise   79     103      120      135
# Bug      NaN       14          Caterpie   45      30       35       20
#          NaN       15           Metapod   50      20       55       25
#          Flying    16        Butterfree   60      45       50       90
#          Poison    17            Weedle   40      35       30       20
#          Poison    18            Kakuna   45      25       50       25
#          Poison    19          Beedrill   65      90       40       45
#          Poison    20     Mega Beedrill   65     150       40       15
# Normal   Flying    21            Pidgey   40      45       40       35
#          Flying    22         Pidgeotto   63      60       55       50
#          Flying    23           Pidgeot   83      80       75       70
#          Flying    24      Mega Pidgeot   83      80       80      135
#          NaN       25           Rattata   30      56       35       25
#          NaN       26          Raticate   55      81       60       50
#          Flying    27           Spearow   40      60       30       31
#          Flying    28            Fearow   65      90       65       61
# Poison   NaN       29             Ekans   35      60       44       40
#          NaN       30             Arbok   60      85       69       65
# ...               ...               ...  ...     ...      ...      ...
# Psychic  NaN       71          Alakazam   55      50       45      135
#          NaN       72     Mega Alakazam   55      50       65      175
# Fighting NaN       73            Machop   70      80       50       35
#          NaN       74           Machoke   80     100       70       50
#          NaN       75           Machamp   90     130       80       65
# Grass    Poison    76        Bellsprout   50      75       35       70
#          Poison    77        Weepinbell   65      90       50       85
#          Poison    78        Victreebel   80     105       65      100
# Water    Poison    79         Tentacool   40      40       35       50
#          Poison    80        Tentacruel   80      70       65       80
# Rock     Ground    81           Geodude   40      80      100       30
#          Ground    82          Graveler   55      95      115       45
#          Ground    83             Golem   80     120      130       55
# Fire     NaN       84            Ponyta   50      85       55       65
#          NaN       85          Rapidash   65     100       70       80
# Water    Psychic   86          Slowpoke   90      65       65       40
#          Psychic   87           Slowbro   95      75      110      100
#          Psychic   88      Mega Slowbro   95      75      180      130
# Electric Steel     89         Magnemite   25      35       70       95
#          Steel     90          Magneton   50      60       95      120
# Normal   Flying    91        Farfetch'd   52      65       55       58
#          Flying    92             Doduo   35      85       45       35
#          Flying    93            Dodrio   60     110       70       60
# Water    NaN       94              Seel   65      45       55       45
#          Ice       95           Dewgong   90      70       80       70
# Poison   NaN       96            Grimer   80      80       50       40
#          NaN       97               Muk  105     105       75       65
# Water    NaN       98          Shellder   30      65      100       45
#          Ice       99          Cloyster   50      95      180       85
# Ghost    Poison   100            Gastly   30      35       30      100
#
#                   Sp. Def  Speed  Generation  Legendary
# Type 1   Type 2
# Grass    Poison        65     45           1      False
#          Poison        80     60           1      False
#          Poison       100     80           1      False
#          Poison       120     80           1      False
# Fire     NaN           50     65           1      False
#          NaN           65     80           1      False
#          Flying        85    100           1      False
#          Dragon        85    100           1      False
#          Flying       115    100           1      False
# Water    NaN           64     43           1      False
#          NaN           80     58           1      False
#          NaN          105     78           1      False
#          NaN          115     78           1      False
# Bug      NaN           20     45           1      False
#          NaN           25     30           1      False
#          Flying        80     70           1      False
#          Poison        20     50           1      False
#          Poison        25     35           1      False
#          Poison        80     75           1      False
#          Poison        80    145           1      False
# Normal   Flying        35     56           1      False
#          Flying        50     71           1      False
#          Flying        70    101           1      False
#          Flying        80    121           1      False
#          NaN           35     72           1      False
#          NaN           70     97           1      False
#          Flying        31     70           1      False
#          Flying        61    100           1      False
# Poison   NaN           54     55           1      False
#          NaN           79     80           1      False
# ...                   ...    ...         ...        ...
# Psychic  NaN           95    120           1      False
#          NaN           95    150           1      False
# Fighting NaN           35     35           1      False
#          NaN           60     45           1      False
#          NaN           85     55           1      False
# Grass    Poison        30     40           1      False
#          Poison        45     55           1      False
#          Poison        70     70           1      False
# Water    Poison       100     70           1      False
#          Poison       120    100           1      False
# Rock     Ground        30     20           1      False
#          Ground        45     35           1      False
#          Ground        65     45           1      False
# Fire     NaN           65     90           1      False
#          NaN           80    105           1      False
# Water    Psychic       40     15           1      False
#          Psychic       80     30           1      False
#          Psychic       80     30           1      False
# Electric Steel         55     45           1      False
#          Steel         70     70           1      False
# Normal   Flying        62     60           1      False
#          Flying        35     75           1      False
#          Flying        60    100           1      False
# Water    NaN           70     45           1      False
#          Ice           95     70           1      False
# Poison   NaN           50     25           1      False
#          NaN          100     50           1      False
# Water    NaN           25     40           1      False
#          Ice           45     70           1      False
# Ghost    Poison        35     80           1      False
#
# [100 rows x 10 columns]

# %%
data1[data1['Legendary']==True]
# Out:
#                      #                       Name   HP  Attack  Defense  \
# Type 1   Type 2
# Ice      Flying    157                   Articuno   90      85      100
# Electric Flying    158                     Zapdos   90      90       85
# Fire     Flying    159                    Moltres   90     100       90
# Psychic  NaN       163                     Mewtwo  106     110       90
#          Fighting  164              Mega Mewtwo X  106     190      100
#          NaN       165              Mega Mewtwo Y  106     150       70
# Electric NaN       263                     Raikou   90      85       75
# Fire     NaN       264                      Entei  115     115       85
# Water    NaN       265                    Suicune  100      75      115
# Psychic  Flying    270                      Lugia  106      90      130
# Fire     Flying    271                      Ho-oh  106     130       90
# Rock     NaN       415                   Regirock   80     100      200
# Ice      NaN       416                     Regice   80      50      100
# Steel    NaN       417                  Registeel   80      75      150
# Dragon   Psychic   418                     Latias   80      80       90
#          Psychic   419                Mega Latias   80     100      120
#          Psychic   420                     Latios   80      90       80
#          Psychic   421                Mega Latios   80     130      100
# Water    NaN       422                     Kyogre  100     100       90
#          NaN       423              Primal Kyogre  100     150       90
# Ground   NaN       424                    Groudon  100     150      140
#          Fire      425             Primal Groudon  100     180      160
# Dragon   Flying    426                   Rayquaza  105     150       90
#          Flying    427              Mega Rayquaza  105     180      100
# Steel    Psychic   428                    Jirachi  100     100      100
# Psychic  NaN       429        Deoxys Normal Forme   50     150       50
#          NaN       430         DeoxysAttack Forme   50     180       20
#          NaN       431       Deoxys Defense Forme   50      70      160
#          NaN       432         Deoxys Speed Forme   50      95       90
#          NaN       538                       Uxie   75      75      130
# ...                ...                        ...  ...     ...      ...
# Normal   NaN       544                  Regigigas  110     160      110
# Ghost    Dragon    545     Giratina Altered Forme  150     100      120
#          Dragon    546      Giratina Origin Forme  150     120      100
# Dark     NaN       550                    Darkrai   70      90       90
# Grass    NaN       551         Shaymin Land Forme  100     100      100
#          Flying    552          Shaymin Sky Forme  100     103       75
# Normal   NaN       553                     Arceus  120     120      120
# Psychic  Fire      554                    Victini  100     100      100
# Steel    Fighting  700                   Cobalion   91      90      129
# Rock     Fighting  701                  Terrakion   91     129       90
# Grass    Fighting  702                   Virizion   91      90       72
# Flying   NaN       703   Tornadus Incarnate Forme   79     115       70
#          NaN       704     Tornadus Therian Forme   79     100       80
# Electric Flying    705  Thundurus Incarnate Forme   79     115       70
#          Flying    706    Thundurus Therian Forme   79     105       70
# Dragon   Fire      707                   Reshiram  100     120      100
#          Electric  708                     Zekrom  100     150      120
# Ground   Flying    709   Landorus Incarnate Forme   89     125       90
#          Flying    710     Landorus Therian Forme   89     145       90
# Dragon   Ice       711                     Kyurem  125     130       90
#          Ice       712        Kyurem Black Kyurem  125     170      100
#          Ice       713        Kyurem White Kyurem  125     120       90
# Fairy    NaN       793                    Xerneas  126     131       95
# Dark     Flying    794                    Yveltal  126     131       95
# Dragon   Ground    795         Zygarde Half Forme  108     100      121
# Rock     Fairy     796                    Diancie   50     100      150
#          Fairy     797               Mega Diancie   50     160      110
# Psychic  Ghost     798             Hoopa Confined   80     110       60
#          Dark      799              Hoopa Unbound   80     160       60
# Fire     Water     800                  Volcanion   80     110      120
#
#                    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1   Type 2
# Ice      Flying         95      125     85           1       True
# Electric Flying        125       90    100           1       True
# Fire     Flying        125       85     90           1       True
# Psychic  NaN           154       90    130           1       True
#          Fighting      154      100    130           1       True
#          NaN           194      120    140           1       True
# Electric NaN           115      100    115           2       True
# Fire     NaN            90       75    100           2       True
# Water    NaN            90      115     85           2       True
# Psychic  Flying         90      154    110           2       True
# Fire     Flying        110      154     90           2       True
# Rock     NaN            50      100     50           3       True
# Ice      NaN           100      200     50           3       True
# Steel    NaN            75      150     50           3       True
# Dragon   Psychic       110      130    110           3       True
#          Psychic       140      150    110           3       True
#          Psychic       130      110    110           3       True
#          Psychic       160      120    110           3       True
# Water    NaN           150      140     90           3       True
#          NaN           180      160     90           3       True
# Ground   NaN           100       90     90           3       True
#          Fire          150       90     90           3       True
# Dragon   Flying        150       90     95           3       True
#          Flying        180      100    115           3       True
# Steel    Psychic       100      100    100           3       True
# Psychic  NaN           150       50    150           3       True
#          NaN           180       20    150           3       True
#          NaN            70      160     90           3       True
#          NaN            95       90    180           3       True
#          NaN            75      130     95           4       True
# ...                    ...      ...    ...         ...        ...
# Normal   NaN            80      110    100           4       True
# Ghost    Dragon        100      120     90           4       True
#          Dragon        120      100     90           4       True
# Dark     NaN           135       90    125           4       True
# Grass    NaN           100      100    100           4       True
#          Flying        120       75    127           4       True
# Normal   NaN           120      120    120           4       True
# Psychic  Fire          100      100    100           5       True
# Steel    Fighting       90       72    108           5       True
# Rock     Fighting       72       90    108           5       True
# Grass    Fighting       90      129    108           5       True
# Flying   NaN           125       80    111           5       True
#          NaN           110       90    121           5       True
# Electric Flying        125       80    111           5       True
#          Flying        145       80    101           5       True
# Dragon   Fire          150      120     90           5       True
#          Electric      120      100     90           5       True
# Ground   Flying        115       80    101           5       True
#          Flying        105       80     91           5       True
# Dragon   Ice           130       90     95           5       True
#          Ice           120       90     95           5       True
#          Ice           170      100     95           5       True
# Fairy    NaN           131       98     99           6       True
# Dark     Flying        131       98     99           6       True
# Dragon   Ground         81       95     95           6       True
# Rock     Fairy         100      150     50           6       True
#          Fairy         160      110    110           6       True
# Psychic  Ghost         150      130     70           6       True
#          Dark          170      130     80           6       True
# Fire     Water         130       90     70           6       True
#
# [65 rows x 10 columns]

# %%
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#    age gender  response treatment
# 0   15      F        10         A
# 1    4      M        45         A
# 2   72      F         5         B
# 3   65      M         9         B

# %%
df.pivot(index="treatment",columns = "gender",values="age")
# Out:
# gender      F   M
# treatment
# A          15   4
# B          72  65

# %%
df1 = df.set_index(['treatment', 'gender'])
df1
# Out:
#                   age  response
# treatment gender
# A         F        15        10
#           M         4        45
# B         F        72         5
#           M        65         9

# %%
df1.unstack(level=0)
# Out:
#           age     response
# treatment   A   B        A  B
# gender
# F          15  72       10  5
# M           4  65       45  9

# %%
df1.unstack(level=1)
# Out:
#           age     response
# gender      F   M        F   M
# treatment
# A          15   4       10  45
# B          72  65        5   9

# %%
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   age  response
# gender treatment
# F      A           15        10
# M      A            4        45
# F      B           72         5
# M      B           65         9

# %%
pd.melt(df,id_vars="treatment",value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %%
df
# Out:
#    age gender  response treatment
# 0   15      F        10         A
# 1    4      M        45         A
# 2   72      F         5         B
# 3   65      M         9         B

# %%
df.groupby("treatment").mean()
# Out:
#             age  response
# treatment
# A           9.5      27.5
# B          68.5       7.0

# %%
df.groupby("treatment").age.mean()
# Out:
# treatment
# A     9.5
# B    68.5
# Name: age, dtype: float64

# %%
df.groupby("treatment")[["age","response"]].mean()
# Out:
#             age  response
# treatment
# A           9.5      27.5
# B          68.5       7.0

# %%
df.info()
df["gender"] = df["gender"].astype("category")
df["treatment"] = df["treatment"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# age          4 non-null int64
# gender       4 non-null object
# response     4 non-null int64
# treatment    4 non-null object
# dtypes: int64(2), object(2)
# memory usage: 200.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# age          4 non-null int64
# gender       4 non-null category
# response     4 non-null int64
# treatment    4 non-null category
# dtypes: category(2), int64(2)
# memory usage: 336.0 bytes
